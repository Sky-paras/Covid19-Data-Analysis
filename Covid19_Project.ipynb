# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

confirmed_cases = pd.read_csv("D:\\Paras\\My Document\\Coding Ninja\\Python\\Case Study\\Covid-19\\covid_19_confirmed.csv")

confirmed_cases.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    64575    65080    65486
# 1        0        0        0        0  ...   132118   132153   132176
# 2        0        0        0        0  ...   126156   126434   126651
# 3        0        0        0        0  ...    13569    13569    13569
# 4        0        0        0        0  ...    31661    31909    32149
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
confirmed_cases.isnull().values.any()
# Out:
# np.True_

# %%
confirmed_cases.shape
# Out:
# (276, 498)

# %%
filepath_death = "D:\\Paras\\My Document\\Coding Ninja\\Python\\Case Study\\Covid-19\\covid_19_deaths.csv"
death_cases = pd.read_csv(filepath_death)
death_cases.head()
# Out:
#           Column1         Column2   Column3    Column4  Column5  Column6  \
# 0  Province/State  Country/Region       Lat       Long  1/22/20  1/23/20
# 1             NaN     Afghanistan  33.93911  67.709953        0        0
# 2             NaN         Albania   41.1533    20.1683        0        0
# 3             NaN         Algeria   28.0339     1.6596        0        0
# 4             NaN         Andorra   42.5063     1.5218        0        0
#
#    Column7  Column8  Column9 Column10  ... Column489 Column490 Column491  \
# 0  1/24/20  1/25/20  1/26/20  1/27/20  ...   5/20/21   5/21/21   5/22/21
# 1        0        0        0        0  ...      2772      2782      2792
# 2        0        0        0        0  ...      2440      2441      2442
# 3        0        0        0        0  ...      3401      3405      3411
# 4        0        0        0        0  ...       127       127       127
#
#   Column492 Column493 Column494 Column495 Column496 Column497 Column498
# ...

# %%
# Promoting The Headers
filepath_death = "D:\\Paras\\My Document\\Coding Ninja\\Python\\Case Study\\Covid-19\\covid_19_deaths.csv"
death_cases = pd.read_csv(filepath_death, header = 1)
death_cases.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...     2772     2782     2792
# 1        0        0        0        0  ...     2440     2441     2442
# 2        0        0        0        0  ...     3401     3405     3411
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      704      709      715
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# Dropping the first rows and reset_index for iloc 
filepath_death = "D:\\Paras\\My Document\\Coding Ninja\\Python\\Case Study\\Covid-19\\covid_19_deaths.csv"
death_cases = pd.read_csv(filepath_death)
death_cases.columns = death_cases.iloc[0]
death_cases = death_cases.drop(0)
death_cases = death_cases.reset_index(drop = True)
death_cases.head()
# Out:
# 0 Province/State Country/Region       Lat       Long 1/22/20 1/23/20 1/24/20  \
# 0            NaN    Afghanistan  33.93911  67.709953       0       0       0
# 1            NaN        Albania   41.1533    20.1683       0       0       0
# 2            NaN        Algeria   28.0339     1.6596       0       0       0
# 3            NaN        Andorra   42.5063     1.5218       0       0       0
# 4            NaN         Angola  -11.2027    17.8739       0       0       0
#
# 0 1/25/20 1/26/20 1/27/20  ... 5/20/21 5/21/21 5/22/21 5/23/21 5/24/21  \
# 0       0       0       0  ...    2772    2782    2792    2802    2812
# 1       0       0       0  ...    2440    2441    2442    2444    2445
# 2       0       0       0  ...    3401    3405    3411    3418    3426
# 3       0       0       0  ...     127     127     127     127     127
# 4       0       0       0  ...     704     709     715     725     731
#
# 0 5/25/21 5/26/21 5/27/21 5/28/21 5/29/21
# ...

# %%
filepath_recovered = "D:\Paras\My Document\Coding Ninja\Python\Case Study\Covid-19\covid_19_recovered.csv"
recovered_cases = pd.read_csv(filepath_recovered)
recovered_cases.head()
# Out:
#           Column1         Column2   Column3    Column4  Column5  Column6  \
# 0  Province/State  Country/Region       Lat       Long  1/22/20  1/23/20
# 1             NaN     Afghanistan  33.93911  67.709953        0        0
# 2             NaN         Albania   41.1533    20.1683        0        0
# 3             NaN         Algeria   28.0339     1.6596        0        0
# 4             NaN         Andorra   42.5063     1.5218        0        0
#
#    Column7  Column8  Column9 Column10  ... Column489 Column490 Column491  \
# 0  1/24/20  1/25/20  1/26/20  1/27/20  ...   5/20/21   5/21/21   5/22/21
# 1        0        0        0        0  ...     55687     55790     55889
# 2        0        0        0        0  ...    127869    128425    128601
# 3        0        0        0        0  ...     87902     88066     88208
# 4        0        0        0        0  ...     13234     13234     13234
#
#   Column492 Column493 Column494 Column495 Column496 Column497 Column498
# ...

# %%
# Dropping the first rows and reset
filepath_recovered = "D:\Paras\My Document\Coding Ninja\Python\Case Study\Covid-19\covid_19_recovered.csv"
recovered_cases = pd.read_csv(filepath_recovered)
recovered_cases.columns = recovered_cases.iloc[0]
recovered_cases = recovered_cases.drop(0).reset_index(drop = True)
recovered_cases.head()
# Out:
# 0 Province/State Country/Region       Lat       Long 1/22/20 1/23/20 1/24/20  \
# 0            NaN    Afghanistan  33.93911  67.709953       0       0       0
# 1            NaN        Albania   41.1533    20.1683       0       0       0
# 2            NaN        Algeria   28.0339     1.6596       0       0       0
# 3            NaN        Andorra   42.5063     1.5218       0       0       0
# 4            NaN         Angola  -11.2027    17.8739       0       0       0
#
# 0 1/25/20 1/26/20 1/27/20  ... 5/20/21 5/21/21 5/22/21 5/23/21 5/24/21  \
# 0       0       0       0  ...   55687   55790   55889   56035   56295
# 1       0       0       0  ...  127869  128425  128601  128732  128826
# 2       0       0       0  ...   87902   88066   88208   88346   88497
# 3       0       0       0  ...   13234   13234   13234   13234   13234
# 4       0       0       0  ...   26483   26513   26775   26778   27087
#
# 0 5/25/21 5/26/21 5/27/21 5/28/21 5/29/21
# ...

# %%
all_cols = confirmed_cases.columns
all_cols
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '5/20/21', '5/21/21', '5/22/21', '5/23/21', '5/24/21', '5/25/21',
#        '5/26/21', '5/27/21', '5/28/21', '5/29/21'],
#       dtype='str', length=498)

# %%
# confirmed_cases.iloc[rows, columns]
date_cols = confirmed_cases.iloc[:, 4:].columns
date_cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '5/20/21', '5/21/21', '5/22/21', '5/23/21', '5/24/21', '5/25/21',
#        '5/26/21', '5/27/21', '5/28/21', '5/29/21'],
#       dtype='str', length=494)

# %%
# pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)[source]
id_vars = ["Province/State", "Country/Region", "Lat", "Long"]
date_cols = [c for c in all_cols if c not in id_vars]
print(date_cols[:10])
# Out:
# ['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20']

# %%
date_cols = []
for c in all_cols:
    if c not in id_vars:
        date_cols.append(c)
print(date_cols[:10])
# Out:
# ['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20']

# %%
# Melt -> Unpiot to the DataFrame
# pandas.melt
# confirmed_cases_long = pd.melt(
#     frame = confirmed_cases,
#     id_vars=["Province/State", "Country/Region", "Lat", "Long"],
#     var_name="Date",
#     value_name="Confirmed"
# )
confirmed_long = confirmed_cases.melt(
    id_vars= id_vars,
    value_vars = date_cols,
    var_name= "Date",
    value_name="Confirmed"
)
print(confirmed_long.head())
# Out:
#   Province/State Country/Region       Lat       Long     Date  Confirmed
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %%
recovered_long = pd.melt(
    frame = recovered_cases,
    id_vars=["Province/State", "Country/Region", "Lat", "Long"],
    var_name="Date",
    value_name="Recovered"
)
recovered_long.head()
# Out:
#   Province/State Country/Region       Lat       Long     Date Recovered
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20         0
# 1            NaN        Albania   41.1533    20.1683  1/22/20         0
# 2            NaN        Algeria   28.0339     1.6596  1/22/20         0
# 3            NaN        Andorra   42.5063     1.5218  1/22/20         0
# 4            NaN         Angola  -11.2027    17.8739  1/22/20         0

# %%
death_long = pd.melt(
    frame = death_cases,
    id_vars=["Province/State", "Country/Region", "Lat", "Long"],
    var_name="Date",
    value_name="Deaths"
)
death_long.head()
# Out:
#   Province/State Country/Region       Lat       Long     Date Deaths
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20      0
# 1            NaN        Albania   41.1533    20.1683  1/22/20      0
# 2            NaN        Algeria   28.0339     1.6596  1/22/20      0
# 3            NaN        Andorra   42.5063     1.5218  1/22/20      0
# 4            NaN         Angola  -11.2027    17.8739  1/22/20      0

# %%
# Structural Insights for each DataFrame() -> rows, cols, dytpes
print(confirmed_long.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136344 entries, 0 to 136343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  42484 non-null   str
#  1   Country/Region  136344 non-null  str
#  2   Lat             135356 non-null  float64
#  3   Long            135356 non-null  float64
#  4   Date            136344 non-null  str
#  5   Confirmed       136344 non-null  int64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 8.7 MB
# None

# %%
print(death_long.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136344 entries, 0 to 136343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  42484 non-null   str
#  1   Country/Region  136344 non-null  str
#  2   Lat             135356 non-null  str
#  3   Long            135356 non-null  str
#  4   Date            136344 non-null  str
#  5   Deaths          136343 non-null  str
# dtypes: str(6)
# memory usage: 10.9 MB
# None

# %%
print(recovered_long.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128934 entries, 0 to 128933
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  34580 non-null   str
#  1   Country/Region  128934 non-null  str
#  2   Lat             128440 non-null  str
#  3   Long            128440 non-null  str
#  4   Date            128934 non-null  str
#  5   Recovered       128933 non-null  str
# dtypes: str(6)
# memory usage: 10.5 MB
# None

# %%
# Identifying missing values
confirmed_long['Lat'].isna().sum()
# Out:
# np.int64(988)

# %%
filter_df = confirmed_long[confirmed_long['Lat'].isna()]
filter_df
# Out:
#                 Province/State Country/Region  Lat  Long     Date  Confirmed
# 52      Repatriated Travellers         Canada  NaN   NaN  1/22/20          0
# 88                     Unknown          China  NaN   NaN  1/22/20          0
# 328     Repatriated Travellers         Canada  NaN   NaN  1/23/20          0
# 364                    Unknown          China  NaN   NaN  1/23/20          0
# 604     Repatriated Travellers         Canada  NaN   NaN  1/24/20          0
# ...                        ...            ...  ...   ...      ...        ...
# 135604                 Unknown          China  NaN   NaN  5/27/21          0
# 135844  Repatriated Travellers         Canada  NaN   NaN  5/28/21         13
# 135880                 Unknown          China  NaN   NaN  5/28/21          0
# 136120  Repatriated Travellers         Canada  NaN   NaN  5/29/21         13
# 136156                 Unknown          China  NaN   NaN  5/29/21          0
#
# [988 rows x 6 columns]

# %%
# Which Country/Region won't have any Lat and Long Values?
filter_df['Country/Region'].unique()
# Out:
# <ArrowStringArray>
# ['Canada', 'China']
# Length: 2, dtype: str

# %%
# Handling Missing Values
confirmed_long['Province/State'].value_counts(dropna = False)
# Out:
# Province/State
# NaN                                             93860
# Australian Capital Territory                      494
# New South Wales                                   494
# Northern Territory                                494
# Queensland                                        494
#                                                 ...
# Gibraltar                                         494
# Isle of Man                                       494
# Montserrat                                        494
# Saint Helena, Ascension and Tristan da Cunha      494
# Turks and Caicos Islands                          494
# Name: count, Length: 87, dtype: int64

# %%
# Confirmed Long  -> Data Cleaning & Hqandling Missing Values
confirmed_long['Province/State'] = confirmed_long['Province/State'].fillna('All Province')
confirmed_long['Lat'] = pd.to_numeric(confirmed_long['Lat']).fillna(0)
confirmed_long['Long'] = pd.to_numeric(confirmed_long['Long']).fillna(0)
confirmed_long['Date'] = pd.to_datetime(confirmed_long['Date'] , format = "%m/%d/%y" , errors = 'coerce')
confirmed_long.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136344 entries, 0 to 136343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  136344 non-null  str
#  1   Country/Region  136344 non-null  str
#  2   Lat             136344 non-null  float64
#  3   Long            136344 non-null  float64
#  4   Date            136344 non-null  datetime64[us]
#  5   Confirmed       136344 non-null  int64
# dtypes: datetime64[us](1), float64(2), int64(1), str(2)
# memory usage: 8.8 MB

# %%
death_long.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136344 entries, 0 to 136343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  42484 non-null   str
#  1   Country/Region  136344 non-null  str
#  2   Lat             135356 non-null  str
#  3   Long            135356 non-null  str
#  4   Date            136344 non-null  str
#  5   Deaths          136343 non-null  str
# dtypes: str(6)
# memory usage: 10.9 MB

# %%
# death Long  -> Data Cleaning & Hqandling Missing Values
death_long['Province/State'] = death_long['Province/State'].fillna('All Province')
death_long['Lat'] = pd.to_numeric(death_long['Lat']).astype("float").fillna(0)
death_long['Long'] = pd.to_numeric(death_long['Long']).astype("float").fillna(0)
death_long['Date'] = pd.to_datetime(death_long['Date'] , format = "%m/%d/%y" , errors = 'coerce')
death_long['Deaths'] = pd.to_numeric(death_long['Deaths']).fillna(0).astype("int64")
death_long.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136344 entries, 0 to 136343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  136344 non-null  str
#  1   Country/Region  136344 non-null  str
#  2   Lat             136344 non-null  float64
#  3   Long            136344 non-null  float64
#  4   Date            136344 non-null  datetime64[us]
#  5   Deaths          136344 non-null  int64
# dtypes: datetime64[us](1), float64(2), int64(1), str(2)
# memory usage: 8.8 MB

# %%
recovered_long.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128934 entries, 0 to 128933
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  34580 non-null   str
#  1   Country/Region  128934 non-null  str
#  2   Lat             128440 non-null  str
#  3   Long            128440 non-null  str
#  4   Date            128934 non-null  str
#  5   Recovered       128933 non-null  str
# dtypes: str(6)
# memory usage: 10.5 MB

# %%
# recovered Long  -> Data Cleaning & Hqandling Missing Values
recovered_long['Province/State'] = recovered_long['Province/State'].fillna('All Province')
recovered_long['Lat'] = pd.to_numeric(recovered_long['Lat']).astype("float").fillna(0)
recovered_long['Long'] = pd.to_numeric(recovered_long['Long']).astype("float").fillna(0)
recovered_long['Date'] = pd.to_datetime(recovered_long['Date'] , format = "%m/%d/%y" , errors = 'coerce')
recovered_long['Recovered'] = pd.to_numeric(recovered_long['Recovered']).fillna(0).astype("int64")
recovered_long.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128934 entries, 0 to 128933
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  128934 non-null  str
#  1   Country/Region  128934 non-null  str
#  2   Lat             128934 non-null  float64
#  3   Long            128934 non-null  float64
#  4   Date            128934 non-null  datetime64[us]
#  5   Recovered       128934 non-null  int64
# dtypes: datetime64[us](1), float64(2), int64(1), str(2)
# memory usage: 8.4 MB

# %%
# Groupby + Aggregation [Country, Date(GroupBy), confimed]
confirmed_cd = (
    confirmed_long
    .groupby(["Country/Region","Date"])['Confirmed']
    .sum()
    .reset_index().sort_values(['Country/Region','Date'])
)
confirmed_cd
# Out:
#       Country/Region       Date  Confirmed
# 0        Afghanistan 2020-01-22          0
# 1        Afghanistan 2020-01-23          0
# 2        Afghanistan 2020-01-24          0
# 3        Afghanistan 2020-01-25          0
# 4        Afghanistan 2020-01-26          0
# ...              ...        ...        ...
# 95337       Zimbabwe 2021-05-25      38706
# 95338       Zimbabwe 2021-05-26      38819
# 95339       Zimbabwe 2021-05-27      38854
# 95340       Zimbabwe 2021-05-28      38918
# 95341       Zimbabwe 2021-05-29      38933
#
# [95342 rows x 3 columns]

# %%
# Groupby + Aggregation [Country, Date(GroupBy), confimed]
deaths_cd = (
    death_long
    .groupby(["Country/Region","Date"])['Deaths']
    .sum()
    .reset_index().sort_values(['Country/Region','Date'])
)
deaths_cd
# Out:
#       Country/Region       Date  Deaths
# 0        Afghanistan 2020-01-22       0
# 1        Afghanistan 2020-01-23       0
# 2        Afghanistan 2020-01-24       0
# 3        Afghanistan 2020-01-25       0
# 4        Afghanistan 2020-01-26       0
# ...              ...        ...     ...
# 95337       Zimbabwe 2021-05-25    1587
# 95338       Zimbabwe 2021-05-26    1589
# 95339       Zimbabwe 2021-05-27    1592
# 95340       Zimbabwe 2021-05-28    1592
# 95341       Zimbabwe 2021-05-29    1594
#
# [95342 rows x 3 columns]

# %%
# Groupby + Aggregation [Country, Date(GroupBy), confimed]
recovered_cd = (
    recovered_long
    .groupby(["Country/Region","Date"])['Recovered']
    .sum()
    .reset_index().sort_values(['Country/Region','Date'])
)
recovered_cd
# Out:
#       Country/Region       Date  Recovered
# 0        Afghanistan 2020-01-22          0
# 1        Afghanistan 2020-01-23          0
# 2        Afghanistan 2020-01-24          0
# 3        Afghanistan 2020-01-25          0
# 4        Afghanistan 2020-01-26          0
# ...              ...        ...        ...
# 95337       Zimbabwe 2021-05-25      36517
# 95338       Zimbabwe 2021-05-26      36531
# 95339       Zimbabwe 2021-05-27      36541
# 95340       Zimbabwe 2021-05-28      36563
# 95341       Zimbabwe 2021-05-29      36578
#
# [95342 rows x 3 columns]

# %%
# pandas.merge()
merged = confirmed_cd.merge(
    recovered_cd,
    on=["Country/Region","Date"],
    how="inner"
).merge(
    deaths_cd,
    on=["Country/Region","Date"],
    how="inner"
).sort_values(['Country/Region','Date'])
merged = merged.fillna(0)
merged.head()
# Out:
#   Country/Region       Date  Confirmed  Recovered  Deaths
# 0    Afghanistan 2020-01-22          0          0       0
# 1    Afghanistan 2020-01-23          0          0       0
# 2    Afghanistan 2020-01-24          0          0       0
# 3    Afghanistan 2020-01-25          0          0       0
# 4    Afghanistan 2020-01-26          0          0       0

# %%
# 2.2 Generate plots of confirmed cases over time for top countries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

latest_dates = merged.groupby("Country/Region")["Date"].max()
latest_dates
# Out:
# Country/Region
# Afghanistan          2021-05-29
# Albania              2021-05-29
# Algeria              2021-05-29
# Andorra              2021-05-29
# Angola               2021-05-29
#                         ...
# Vietnam              2021-05-29
# West Bank and Gaza   2021-05-29
# Yemen                2021-05-29
# Zambia               2021-05-29
# Zimbabwe             2021-05-29
# Name: Date, Length: 193, dtype: datetime64[us]

# %%
# New DataFrame()
latest_totals = merged.copy() # Shallow Copy
latest_totals = latest_totals[latest_totals['Date'] == '2021-05-29']
latest_totals.head()
# Out:
#      Country/Region       Date  Confirmed  Recovered  Deaths
# 493     Afghanistan 2021-05-29      70111      57281    2899
# 987         Albania 2021-05-29     132297     129215    2449
# 1481        Algeria 2021-05-29     128456      89419    3460
# 1975        Andorra 2021-05-29      13693      13416     127
# 2469         Angola 2021-05-29      34180      27646     757

# %%
# Hypothetical Situation Considering ['Dates'] are not the same for all the countries
latest_totals = (
    merged.merge(latest_dates.rename('LatestDate'),
                on = ['Country/Region'], how = 'inner')
                .query('Date == LatestDate')
)
latest_totals.head()
# Out:
#      Country/Region       Date  Confirmed  Recovered  Deaths LatestDate
# 493     Afghanistan 2021-05-29      70111      57281    2899 2021-05-29
# 987         Albania 2021-05-29     132297     129215    2449 2021-05-29
# 1481        Algeria 2021-05-29     128456      89419    3460 2021-05-29
# 1975        Andorra 2021-05-29      13693      13416     127 2021-05-29
# 2469         Angola 2021-05-29      34180      27646     757 2021-05-29

# %%
latest_totals = latest_totals.set_index('Country/Region')['Confirmed']
latest_totals
# Out:
# Country/Region
# Afghanistan            70111
# Albania               132297
# Algeria               128456
# Andorra                13693
# Angola                 34180
#                        ...
# Vietnam                 6908
# West Bank and Gaza    307838
# Yemen                   6731
# Zambia                 94751
# Zimbabwe               38933
# Name: Confirmed, Length: 193, dtype: int64

# %%
top_5_countries = latest_totals.nlargest(5)
top_5_countries
# Out:
# Country/Region
# US        33251939
# India     27894800
# Brazil    16471600
# France     5719877
# Turkey     5235978
# Name: Confirmed, dtype: int64

# %%
top_5_countries = top_5_countries.index
top_5_countries
# Out:
# Index(['US', 'India', 'Brazil', 'France', 'Turkey'], dtype='str', name='Country/Region')

# %%
# Visualisation [Over Time] [Line Plot]
plt.figure(figsize = (14,9))

for country in top_5_countries:
    top_countries = (merged[merged['Country/Region'] == country]).sort_values('Date')
    print(top_countries)
# Out:
#       Country/Region       Date  Confirmed  Recovered  Deaths
# 88426             US 2020-01-22          1          0       0
# 88427             US 2020-01-23          1          0       0
# 88428             US 2020-01-24          2          0       0
# 88429             US 2020-01-25          2          0       0
# 88430             US 2020-01-26          5          0       0
# ...              ...        ...        ...        ...     ...
# 88915             US 2021-05-25   33166418          0  590941
# 88916             US 2021-05-26   33190470          0  591950
# 88917             US 2021-05-27   33217995          0  593288
# 88918             US 2021-05-28   33239963          0  593963
# 88919             US 2021-05-29   33251939          0  594306
#
# [494 rows x 5 columns]
#       Country/Region       Date  Confirmed  Recovered  Deaths
# 39026          India 2020-01-22          0          0       0
# 39027          India 2020-01-23          0          0       0
# ...

# %%
# Visualisation [Over Time] [Line Plot]
plt.figure(figsize = (14,9))

for country in top_5_countries:
    top_countries = (merged[merged['Country/Region'] == country]).sort_values('Date')
    plt.plot(top_countries['Date'], top_countries['Confirmed'], label = country)
    
plt.title('Total Confirmed Cases Over Time For Top 5 Countries', color = 'red')
plt.xlabel('Dates')
plt.ylabel('Confirmed Cases')
plt.legend()
plt.show()

# %% [markdown]
# # Insights
# 🇺🇸 United States
# Key Insights:
#
# - Fast acceleration from June 2020 onward
# - Major surge between Nov 2020 – Jan 2021
# - Crossed ~33M cases by mid-2021 (highest among all)
#
# Interpretation:
#
# - Multiple strong waves
# - Winter 2020 wave was the most severe
# - Sustained high transmission rate
#
# 📌 Business-style insight:
#
# US had the highest cumulative burden and most aggressive winter surge among the top countries.
#
# 🇮🇳 India
# Key Insights:
#
# - Moderate growth in 2020
# - Massive surge in April–May 2021
# - Sharpest late-stage acceleration among all countries
#
# Interpretation:
#
# - Second wave impact clearly visible
# - Very steep slope = high daily new cases
#
# 📌 Insight:
#
# India experienced a delayed but extremely intense second wave compared to the US.
#
# 🇧🇷 Brazil
# Key Insights:
#
# - Consistent upward trend throughout
# - No strong flattening phase
# - Steady acceleration into 2021
#
# Interpretation:
#
# - Persistent transmission
# - Long-duration wave pattern
#
# 📌 Insight:
#
# Brazil shows sustained spread without prolonged plateau periods.
#
# 🇫🇷 France
# Key Insights:
#
# - Smaller base in early 2020
# - Noticeable acceleration after Oct 2020
# - Gradual but steady increase into 2021
#
# 📌 Insight:
#
# France experienced structured waves but at a lower cumulative scale compared to US/India/Brazil.
#
# 🇹🇷 Turkey
# Key Insights:
#
# - Slower early growth
# - Sharp jump around late 2020 (possible reporting adjustment or wave)
# - Moderate steady increase afterward
#
# 📌 Insight:
#
# Turkey shows reporting shift + controlled but increasing case trajectory.
#
# 📊 Comparative Observations
# 🔹 Highest Total Cases:
#
# US > India > Brazil > France > Turkey
#
# 🔹 Most Aggressive Wave (Slope Steepness):
#
# India (April 2021)
#
# 🔹 Most Consistent Spread:
#
# Brazil
#
# 🔹 Earliest Major Surge:
#
# US (mid-2020)

# %%
# 2.3 Generate plots of confirmed cases over time for China.
# Visulalizations
plt.figure(figsize = (14,9))

top_countries = (merged[merged['Country/Region'] == 'China']).sort_values('Date')
plt.plot(top_countries['Date'], top_countries['Confirmed'], label = 'China')
    
plt.title('Total Confirmed Cases Over Time For China', color = 'red')
plt.xlabel('Dates')
plt.ylabel('Confirmed Cases')
plt.legend()
plt.show()

# %% [markdown]
# # Insights
# 🔎 Key Observations:
#
# - Extremely sharp rise in Jan–Feb 2020
# - Rapid flattening after March 2020
# - Very minimal growth afterward
# - Total cases ~102,960 by mid-2021
#
# Interpretation:
#
# - Early outbreak origin
# - Very strong containment measures
# - Near-flat curve after initial wave
#
# 📌 Major Insight:
#
# China shows a classic “containment curve” — rapid spike followed by long-term stabilization.

# %%
# 2.3 Generate plots of confirmed cases over time for China.
china = confirmed_long[confirmed_long['Country/Region'] == 'China'].copy()
china
# Out:
#        Province/State Country/Region      Lat      Long       Date  Confirmed
# 58              Anhui          China  31.8257  117.2264 2020-01-22          1
# 59            Beijing          China  40.1824  116.4142 2020-01-22         14
# 60          Chongqing          China  30.0572  107.8740 2020-01-22          6
# 61             Fujian          China  26.0789  117.9874 2020-01-22          1
# 62              Gansu          China  35.7518  104.2861 2020-01-22          0
# ...               ...            ...      ...       ...        ...        ...
# 136155          Tibet          China  31.6927   88.0924 2021-05-29          1
# 136156        Unknown          China   0.0000    0.0000 2021-05-29          0
# 136157       Xinjiang          China  41.1129   85.2401 2021-05-29        980
# 136158         Yunnan          China  24.9740  101.4870 2021-05-29        352
# 136159       Zhejiang          China  29.1832  120.0934 2021-05-29       1364
#
# [16796 rows x 6 columns]

# %%
china = china.groupby(['Province/State','Date'])['Confirmed'].sum().reset_index()
china
# Out:
#       Province/State       Date  Confirmed
# 0              Anhui 2020-01-22          1
# 1              Anhui 2020-01-23          9
# 2              Anhui 2020-01-24         15
# 3              Anhui 2020-01-25         39
# 4              Anhui 2020-01-26         60
# ...              ...        ...        ...
# 16791       Zhejiang 2021-05-25       1363
# 16792       Zhejiang 2021-05-26       1363
# 16793       Zhejiang 2021-05-27       1363
# 16794       Zhejiang 2021-05-28       1364
# 16795       Zhejiang 2021-05-29       1364
#
# [16796 rows x 3 columns]

# %%
china['Province/State'].unique()
# Out:
# <ArrowStringArray>
# [         'Anhui',        'Beijing',      'Chongqing',         'Fujian',
#           'Gansu',      'Guangdong',        'Guangxi',        'Guizhou',
#          'Hainan',          'Hebei',   'Heilongjiang',          'Henan',
#       'Hong Kong',          'Hubei',          'Hunan', 'Inner Mongolia',
#         'Jiangsu',        'Jiangxi',          'Jilin',       'Liaoning',
#           'Macau',        'Ningxia',        'Qinghai',        'Shaanxi',
#        'Shandong',       'Shanghai',         'Shanxi',        'Sichuan',
#         'Tianjin',          'Tibet',        'Unknown',       'Xinjiang',
#          'Yunnan',       'Zhejiang']
# Length: 34, dtype: str

# %%
china_wide = china.pivot(
    index = 'Date',
    columns = 'Province/State',
    values = 'Confirmed'
).sort_index()
china_wide.head()
# Out:
# Province/State  Anhui  Beijing  Chongqing  Fujian  Gansu  Guangdong  Guangxi  \
# Date
# 2020-01-22          1       14          6       1      0         26        2
# 2020-01-23          9       22          9       5      2         32        5
# 2020-01-24         15       36         27      10      2         53       23
# 2020-01-25         39       41         57      18      4         78       23
# 2020-01-26         60       68         75      35      7        111       36
#
# Province/State  Guizhou  Hainan  Hebei  ...  Shandong  Shanghai  Shanxi  \
# Date                                    ...
# 2020-01-22            1       4      1  ...         2         9       1
# 2020-01-23            3       5      1  ...         6        16       1
# 2020-01-24            3       8      2  ...        15        20       1
# 2020-01-25            4      19      8  ...        27        33       6
# 2020-01-26            5      22     13  ...        46        40       9
#
# ...

# %%
# Top 5 Provinces/States
top_prov = china_wide.iloc[-1].nlargest(5)
top_prov
# Out:
# Province/State
# Hubei           68159
# Hong Kong       11837
# Guangdong        2432
# Shanghai         2093
# Heilongjiang     1612
# Name: 2021-05-29 00:00:00, dtype: int64

# %%
top_prov.index
# Out:
# Index(['Hubei', 'Hong Kong', 'Guangdong', 'Shanghai', 'Heilongjiang'], dtype='str', name='Province/State')

# %%
china_wide = china_wide[top_prov.index]
china_wide
# Out:
# Province/State  Hubei  Hong Kong  Guangdong  Shanghai  Heilongjiang
# Date
# 2020-01-22        444          0         26         9             0
# 2020-01-23        444          2         32        16             2
# 2020-01-24        549          2         53        20             4
# 2020-01-25        761          5         78        33             9
# 2020-01-26       1058          8        111        40            15
# ...               ...        ...        ...       ...           ...
# 2021-05-25      68159      11835       2413      2078          1612
# 2021-05-26      68159      11836       2427      2079          1612
# 2021-05-27      68159      11836       2428      2081          1612
# 2021-05-28      68159      11836       2431      2088          1612
# 2021-05-29      68159      11837       2432      2093          1612
#
# [494 rows x 5 columns]

# %%
# Visulalizations
ax = china_wide.plot(figsize =(14,9))
ax.set_title('Covid-19 Confirmed Cases Over Time in China.')
ax.set_xlabel('Dates')
ax.set_ylabel('Confirmed Cases')
ax.legend(top_prov.index)
# plt.savefig("covid_confirmed_china.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # insights
# 📊 High-Level Insight
#
# China’s total cases were heavily concentrated in Hubei, while other regions experienced relatively controlled and moderate outbreaks.
#
# This shows strong geographic concentration of the initial wave.
#
# 🔎 Region-wise Analysis
# 🟦 Hubei (Epicenter)
# Key Observations:
#
# - Extremely sharp spike in early 2020 (Jan–Feb)
# - Rapid jump from near 0 to ~68,000+
# - Curve flattens almost completely after March 2020
# - Very minimal growth afterward
#
# Interpretation:
#
# - Hubei was the epicenter (Wuhan outbreak)
# - Aggressive lockdown measures flattened the curve
# - Strong containment after first wave
#
# 📌 Insight:
#
# Nearly the entire national surge was driven by Hubei during the first quarter of 2020.
#
# 🟧 Hong Kong
# Key Observations:
#
# - Gradual increase through 2020
# - Noticeable wave around mid-2020
# - Another steady increase late 2020 → early 2021
# - Reaches ~12,000 cases by mid-2021
#
# Interpretation:
#
# - Multiple smaller waves
# - Imported cases + urban density effect
# - Less extreme than Hubei but persistent spread
#
# 📌 Insight:
#
# Hong Kong shows recurring wave patterns unlike mainland provinces.
#
# 🟩 Guangdong
# Key Observations:
#
# - Early small increase
# - Slow steady growth
# - No explosive spikes
# - Reaches ~2,500 cases
#
# 📌 Insight:
#
# Guangdong maintained strong outbreak control with minor flare-ups.
#
# 🟥 Shanghai
# Key Observations:
#
# - Very gradual growth
# - No visible sharp spikes
# - Controlled curve throughout
#
# 📌 Insight:
#
# Shanghai maintained consistent containment with limited transmission.
#
# 🟪 Heilongjiang
# Key Observations:
#
# - Very low cases early
# - Small noticeable jump around early 2021
# - Possibly border-related wave
#
# 📌 Insight:
#
# Regional outbreaks occurred but were quickly contained.
#
# 📈 Comparative Insights
#
# - Hubei - (Massive early spike pattern, Very High (initially) &	Single major wave)
# - Hong Kong - (Multiple increases pattern, Moderate risk, Recurring waves)
# - Guangdong - (Slow steady pattern, Low risk, Controlled waves)
# - Shanghai - (Flat trend, Very Low risk, Minimal waves)
# - Heilongjiang - (Minor spike pattern, Low risk, Isolated outbreak)

# %%
# 5.1 Analyze the peak number of daily new cases in Germany, France, and Italy.
# Which country experienced the highest single-day surge, and when did it occur?
target_country = ['Germany','France','Italy']
country_date_total = (
    merged.loc[merged['Country/Region'].isin(target_country)]
    .groupby(['Country/Region','Date'])['Confirmed'].sum().reset_index()
)
country_date_total
# Out:
#      Country/Region       Date  Confirmed
# 0            France 2020-01-22          0
# 1            France 2020-01-23          0
# 2            France 2020-01-24          2
# 3            France 2020-01-25          3
# 4            France 2020-01-26          3
# ...             ...        ...        ...
# 1477          Italy 2021-05-25    4197892
# 1478          Italy 2021-05-26    4201827
# 1479          Italy 2021-05-27    4205970
# 1480          Italy 2021-05-28    4209707
# 1481          Italy 2021-05-29    4213055
#
# [1482 rows x 3 columns]

# %%
# Cumulative -> Daily new confirmed cases within each country -> .diff()
country_date_total['DailyNew'] = (
    country_date_total.groupby('Country/Region')['Confirmed'].diff()
    .fillna(0).clip(lower=0)
)
country_date_total
# Out:
#      Country/Region       Date  Confirmed  DailyNew
# 0            France 2020-01-22          0       0.0
# 1            France 2020-01-23          0       0.0
# 2            France 2020-01-24          2       2.0
# 3            France 2020-01-25          3       1.0
# 4            France 2020-01-26          3       0.0
# ...             ...        ...        ...       ...
# 1477          Italy 2021-05-25    4197892    3220.0
# 1478          Italy 2021-05-26    4201827    3935.0
# 1479          Italy 2021-05-27    4205970    4143.0
# 1480          Italy 2021-05-28    4209707    3737.0
# 1481          Italy 2021-05-29    4213055    3348.0
#
# [1482 rows x 4 columns]

# %%
daily_new_matrix = country_date_total.pivot(
    index = 'Date',
    columns = 'Country/Region',
    values = 'DailyNew'
)
daily_new_matrix
# Out:
# Country/Region   France  Germany   Italy
# Date
# 2020-01-22          0.0      0.0     0.0
# 2020-01-23          0.0      0.0     0.0
# 2020-01-24          2.0      0.0     0.0
# 2020-01-25          1.0      0.0     0.0
# 2020-01-26          0.0      0.0     0.0
# ...                 ...      ...     ...
# 2021-05-25       3155.0   2578.0  3220.0
# 2021-05-26      12657.0   4473.0  3935.0
# 2021-05-27      13933.0   6949.0  4143.0
# 2021-05-28      11274.0   6169.0  3737.0
# 2021-05-29      11527.0   4513.0  3348.0
#
# [494 rows x 3 columns]

# %%
daily_new_matrix['France'].nlargest(5)
# Out:
# Date
# 2021-04-11    117900.0
# 2020-11-02    106091.0
# 2021-04-08     97170.0
# 2020-11-07     86655.0
# 2021-04-04     80629.0
# Name: France, dtype: float64

# %%
daily_new_matrix['Germany'].nlargest(5)
# Out:
# Date
# 2020-12-30    49044.0
# 2021-01-07    45333.0
# 2020-12-22    36153.0
# 2020-12-15    33825.0
# 2020-12-23    33758.0
# Name: Germany, dtype: float64

# %%
daily_new_matrix['Italy'].nlargest(5)
# Out:
# Date
# 2020-11-13    40902.0
# 2020-11-07    39809.0
# 2020-11-12    37977.0
# 2020-11-06    37802.0
# 2020-11-14    37249.0
# Name: Italy, dtype: float64

# %%
daily_new_by_company ={}
# target Countries = ['France','Germany','Italy']
for country in target_country:
    if country in daily_new_matrix.columns:
        s = daily_new_matrix[country]
        daily_new_by_company[country] = s

daily_new_by_company
# Out:
# {'Germany': Date
#  2020-01-22       0.0
#  2020-01-23       0.0
#  2020-01-24       0.0
#  2020-01-25       0.0
#  2020-01-26       0.0
#                 ...
#  2021-05-25    2578.0
#  2021-05-26    4473.0
#  2021-05-27    6949.0
#  2021-05-28    6169.0
#  2021-05-29    4513.0
#  Name: Germany, Length: 494, dtype: float64,
#  'France': Date
#  2020-01-22        0.0
#  2020-01-23        0.0
#  2020-01-24        2.0
#  2020-01-25        1.0
#  2020-01-26        0.0
#                 ...
#  2021-05-25     3155.0
#  2021-05-26    12657.0
#  2021-05-27    13933.0
#  2021-05-28    11274.0
#  2021-05-29    11527.0
#  Name: France, Length: 494, dtype: float64,
#  'Italy': Date
#  2020-01-22       0.0
#  2020-01-23       0.0
#  2020-01-24       0.0
#  2020-01-25       0.0
#  2020-01-26       0.0
#                 ...
#  2021-05-25    3220.0
#  2021-05-26    3935.0
#  2021-05-27    4143.0
#  2021-05-28    3737.0
#  2021-05-29    3348.0
#  Name: Italy, Length: 494, dtype: float64}

# %%
# Peaks {Country : (max_value, date)}
peaks = {}
for country, series in daily_new_by_company.items():
    max_value = int(series.max())
    max_index = series.idxmax()
    peaks[country] = (max_value, max_index)

peaks
# Out:
# {'Germany': (49044, Timestamp('2020-12-30 00:00:00')),
#  'France': (117900, Timestamp('2021-04-11 00:00:00')),
#  'Italy': (40902, Timestamp('2020-11-13 00:00:00'))}

# %%
# Visualization
plt.figure(figsize = (12,6))
for country, series in daily_new_by_company.items():
    plt.plot(series.index, series.values, label = country)

plt.title("Daily New Covid-19 Cases for Germany, France & Italy", color = 'red')
plt.xlabel('Date')
plt.xlabel('New Confirmed Cases')
plt.legend()
plt.show()

# %% [markdown]
# # Insight
# Based on the chart:
#
# 🇫🇷 France
#
# - Highest single-day surge among all three countries
# - Peak appears around April 2021
# - Approximate peak value: ~118,000 daily cases
# - Represents the most severe short-term spike in the dataset
#
# 🇩🇪 Germany
#
# - Peak observed around December 2020 – January 2021
# - Approximate maximum: ~45,000–50,000 daily cases
# - Significant winter wave surge
#
# 🇮🇹 Italy
#
# - Peak observed around November 2020
# - Approximate maximum: ~40,000 daily cases
# - Strong second-wave impact
#
# ✅ Conclusion
#
# France experienced the highest single-day surge, occurring approximately in April 2021, significantly exceeding the peak levels of Germany and Italy.

# %%
# 5.2 Compare the recovery rates (recoveries/confirmed cases) between Canada and Australia as of December 31, 2020. 
# Which country showed better management of the pandemic according to this metric?

countries = ['Canada','Australia']
target_date = pd.Timestamp('2020-12-31')

# Label Based Indexing / Filter .loc[]
recover_rates = (
    merged.loc[(merged['Country/Region'].isin(countries)) & (merged['Date'] == target_date), # Rows
    ['Country/Region','Recovered','Confirmed']] # Columns
    .reset_index(drop = True)
)

recover_rates.head()
# Out:
#   Country/Region  Recovered  Confirmed
# 0      Australia      22565      28425
# 1         Canada     493638     584409

# %%
recover_rates['RecoveryRate%'] = (recover_rates["Recovered"] / recover_rates["Confirmed"]* 100).round(2)
recover_rates
# Out:
#   Country/Region  Recovered  Confirmed  RecoveryRate%
# 0      Australia      22565      28425          79.38
# 1         Canada     493638     584409          84.47

# %%
# Column Chart [Visulaization]
plt.figure(figsize = (7,4))
bars = plt.bar(recover_rates['Country/Region'], recover_rates['RecoveryRate%'], color = ['#F54927','#2731F5'])

plt.title("Recovery Rate % b/w Australia & Canada", color = 'red')
plt.xlabel('Country')
plt.xlabel('Recovery Rate %')
plt.ylim(0, 100)
plt.bar_label(bars , fmt = '%.2f%%')
plt.show()

# %% [markdown]
# # Insight
# Recovery Rate Analysis (As of December 31, 2020)
# 📊 Key Findings
#
# 1. Higher Recovery Rate – Canada
# - Canada recorded a recovery rate of 84.47%.
# - Indicates a comparatively stronger recovery performance relative to total confirmed cases.
#
# 2. Australia Recovery Performance
#
# - Australia recorded a recovery rate of 79.38%.
# - Slightly lower than Canada by approximately 5 percentage points.
#
# 3. Comparative Gap
#
# - The recovery rate difference (~5%) suggests variation in:
#     - Case management efficiency
#     - Healthcare response capacity
#
# 📌 Executive Summary
#
# As of December 31, 2020, both Australia and Canada demonstrated strong COVID-19 recovery outcomes, with Canada achieving a slightly higher recovery rate (84.47%) compared to Australia (79.38%). The performance difference suggests variations in case management dynamics but indicates overall effective pandemic response in both countries.

# %%
# 5.3 What is the distribution of death rates (deaths/confirmed cases) among provinces in Canada? 
# Identify the province with the highest and lowest death rate as of the latest data point.

confirmed_long[confirmed_long['Country/Region'] == 'Canada']
# Out:
#                 Province/State Country/Region      Lat      Long       Date  \
# 39                     Alberta         Canada  53.9333 -116.5765 2020-01-22
# 40            British Columbia         Canada  53.7267 -127.6476 2020-01-22
# 41            Diamond Princess         Canada   0.0000    0.0000 2020-01-22
# 42              Grand Princess         Canada   0.0000    0.0000 2020-01-22
# 43                    Manitoba         Canada  53.7609  -98.8139 2020-01-22
# ...                        ...            ...      ...       ...        ...
# 136118    Prince Edward Island         Canada  46.5107  -63.4168 2021-05-29
# 136119                  Quebec         Canada  52.9399  -73.5491 2021-05-29
# 136120  Repatriated Travellers         Canada   0.0000    0.0000 2021-05-29
# 136121            Saskatchewan         Canada  52.9399 -106.4509 2021-05-29
# 136122                   Yukon         Canada  64.2823 -135.0000 2021-05-29
#
#         Confirmed
# 39              0
# ...

# %%
death_long[death_long['Country/Region'] == 'Canada']
# Out:
#                 Province/State Country/Region      Lat      Long       Date  \
# 39                     Alberta         Canada  53.9333 -116.5765 2020-01-22
# 40            British Columbia         Canada  53.7267 -127.6476 2020-01-22
# 41            Diamond Princess         Canada   0.0000    0.0000 2020-01-22
# 42              Grand Princess         Canada   0.0000    0.0000 2020-01-22
# 43                    Manitoba         Canada  53.7609  -98.8139 2020-01-22
# ...                        ...            ...      ...       ...        ...
# 136118    Prince Edward Island         Canada  46.5107  -63.4168 2021-05-29
# 136119                  Quebec         Canada  52.9399  -73.5491 2021-05-29
# 136120  Repatriated Travellers         Canada   0.0000    0.0000 2021-05-29
# 136121            Saskatchewan         Canada  52.9399 -106.4509 2021-05-29
# 136122                   Yukon         Canada  64.2823 -135.0000 2021-05-29
#
#         Deaths
# 39           0
# 40           0
# ...

# %%
canada_confirmed_cases = (
    confirmed_long[confirmed_long['Country/Region'] == 'Canada'].sort_values('Date')
    .groupby(['Province/State']).tail(1)[['Province/State','Confirmed']]
    .set_index('Province/State')
)
canada_confirmed_cases
# Out:
#                            Confirmed
# Province/State
# Repatriated Travellers            13
# Quebec                        369728
# Prince Edward Island             200
# Ontario                       537138
# Nunavut                          648
# Nova Scotia                     5530
# Northwest Territories            127
# Manitoba                       50499
# New Brunswick                   2191
# Grand Princess                    13
# Diamond Princess                   0
# British Columbia              143581
# Alberta                       226855
# Saskatchewan                   46464
# Newfoundland and Labrador       1302
# Yukon                             84

# %%
canada_death_cases = (
    death_long[death_long['Country/Region'] == 'Canada'].sort_values('Date')
    .groupby(['Province/State']).tail(1)[['Province/State','Deaths']]
    .set_index('Province/State')
)
canada_death_cases
# Out:
#                            Deaths
# Province/State
# Repatriated Travellers          0
# Quebec                      11125
# Prince Edward Island            0
# Ontario                      8698
# Nunavut                         4
# Nova Scotia                    84
# Northwest Territories           0
# Manitoba                     1045
# New Brunswick                  43
# Grand Princess                  0
# Diamond Princess                1
# British Columbia             1692
# Alberta                      2214
# Saskatchewan                  537
# Newfoundland and Labrador       6
# Yukon                           2

# %%
canada = canada_confirmed_cases.join(canada_death_cases, how = 'inner')
canada['DeathRate'] = (canada['Deaths']/canada['Confirmed']*100).round(2).replace([np.inf], 0)
canada
# Out:
#                            Confirmed  Deaths  DeathRate
# Province/State
# Repatriated Travellers            13       0       0.00
# Quebec                        369728   11125       3.01
# Prince Edward Island             200       0       0.00
# Ontario                       537138    8698       1.62
# Nunavut                          648       4       0.62
# Nova Scotia                     5530      84       1.52
# Northwest Territories            127       0       0.00
# Manitoba                       50499    1045       2.07
# New Brunswick                   2191      43       1.96
# Grand Princess                    13       0       0.00
# Diamond Princess                   0       1       0.00
# British Columbia              143581    1692       1.18
# Alberta                       226855    2214       0.98
# Saskatchewan                   46464     537       1.16
# Newfoundland and Labrador       1302       6       0.46
# ...

# %%
# Visualisation [Bar Plot]
plt.figure(figsize = (14,8))
canada['DeathRate'].sort_values(ascending = False).plot(kind = 'bar')
ax = plt.title('Covid-19 Death Rate Comparison on All Provinces of Canada', color = 'red')
plt.xlabel('Province/State')
plt.ylabel('Cases')
plt.xticks(rotation = 45)
plt.show()

# %%
# 6.2  What is the total number of deaths reported per country up to the current date?
latest_date = merged['Date'].max()
latest_date
# Out:
# Timestamp('2021-05-29 00:00:00')

# %%
latest_deaths = merged[merged['Date'] == latest_date]
latest_deaths
# Out:
#            Country/Region       Date  Confirmed  Recovered  Deaths
# 493           Afghanistan 2021-05-29      70111      57281    2899
# 987               Albania 2021-05-29     132297     129215    2449
# 1481              Algeria 2021-05-29     128456      89419    3460
# 1975              Andorra 2021-05-29      13693      13416     127
# 2469               Angola 2021-05-29      34180      27646     757
# ...                   ...        ...        ...        ...     ...
# 93365             Vietnam 2021-05-29       6908       2896      47
# 93859  West Bank and Gaza 2021-05-29     307838     300524    3492
# 94353               Yemen 2021-05-29       6731       3399    1319
# 94847              Zambia 2021-05-29      94751      91594    1276
# 95341            Zimbabwe 2021-05-29      38933      36578    1594
#
# [193 rows x 5 columns]

# %%
# Total Number of Deaths reported per country
total_deaths_by_country = (
    latest_deaths.groupby('Country/Region')['Deaths'].sum()
    .sort_values(ascending = False).reset_index()
)
df_df1 = total_deaths_by_country.head(10).set_index('Country/Region')
df_df1
# Out:
#                 Deaths
# Country/Region
# US              594306
# Brazil          461057
# India           325972
# Mexico          223455
# United Kingdom  128037
# Italy           126002
# Russia          118781
# France          109518
# Germany          88413
# Colombia         87747

# %%
# Visualisation [Bar Plot]
plt.figure(figsize = (14,8))
df = df_df1['Deaths'].sort_values(ascending = False).plot(kind = 'bar')
plt.title('Covid-19 Death Rate Comparison', color = 'red')
plt.xlabel('Country/Region')
plt.ylabel('Death Cases')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Insight
# The chart compares COVID-19 death rates (%) across Canadian provinces and territories. There is noticeable variation, indicating regional differences in pandemic impact and healthcare outcomes.
#
# 📌 Key Findings
# 1. Highest Death Rate – Quebec (~3.0%)
#
# - Quebec recorded the highest death rate among all provinces.
# - Significantly above the national average range.
# - Indicates severe early wave impact, particularly in long-term care facilities.
#
# 2. Second Highest – Yukon (~2.4%)
#
# - Higher than most large provinces.
# - Likely influenced by:
#     - Smaller population base-
#     - Healthcare accessibility challenges
#     - Statistical sensitivity (small denominator effect)
#
# 3. Mid-Range Provinces (1.5% – 2.1%)
#
# - Manitoba
# - New Brunswick
# - Ontario
# - Nova Scotia
# These provinces show moderate fatality impact, suggesting:
# - Controlled but substantial pandemic burden.
# - Balanced case management outcomes.
#
# 4. Lower Death Rate Provinces (<1.2%)
#
# - British Columbia
# - Saskatchewan
# - Alberta
# - Nunavut
# - Newfoundland and Labrador
# These regions maintained relatively lower fatality ratios, indicating:
# - Effective healthcare response
# - Lower outbreak intensity
# - Possibly a younger demographic distribution
#
# 5. Minimal / Near-Zero Death Rates
#
# - Northwest Territories
# - Prince Edward Island
# - Diamond Princess
# - Grand Princess
# These reflect:
# - Very low case volumes
# - Controlled outbreaks
# - Isolated or contained environments
#
# 📌 Executive Summary
#
# The death rate distribution across Canadian provinces reveals significant regional disparity, with Quebec exhibiting the highest mortality ratio (~3%), while several western provinces and territories maintained comparatively lower rates. The variation suggests differences in outbreak severity, demographic structure, healthcare system response, and containment effectiveness.

# %%
# 6.3 What are the top 5 countries with the highest average daily deaths? 
m = merged.sort_values(['Country/Region', 'Date']).copy() # Shallow Copy
m['DailyDeaths'] = (
    m.groupby('Country/Region')['Deaths'].diff().fillna(0).clip(lower=0)
)
m
# Out:
#       Country/Region       Date  Confirmed  Recovered  Deaths  DailyDeaths
# 0        Afghanistan 2020-01-22          0          0       0          0.0
# 1        Afghanistan 2020-01-23          0          0       0          0.0
# 2        Afghanistan 2020-01-24          0          0       0          0.0
# 3        Afghanistan 2020-01-25          0          0       0          0.0
# 4        Afghanistan 2020-01-26          0          0       0          0.0
# ...              ...        ...        ...        ...     ...          ...
# 95337       Zimbabwe 2021-05-25      38706      36517    1587          1.0
# 95338       Zimbabwe 2021-05-26      38819      36531    1589          2.0
# 95339       Zimbabwe 2021-05-27      38854      36541    1592          3.0
# 95340       Zimbabwe 2021-05-28      38918      36563    1592          0.0
# 95341       Zimbabwe 2021-05-29      38933      36578    1594          2.0
#
# [95342 rows x 6 columns]

# %%
df = m.groupby('Country/Region')['DailyDeaths'].mean().to_frame(name = 'Daily_Avg_Death').sort_values('Daily_Avg_Death', ascending = False)
df
# Out:
#                        Daily_Avg_Death
# Country/Region
# US                         1203.048583
# Brazil                      933.313765
# India                       659.864372
# Mexico                      452.338057
# United Kingdom              259.184211
# ...                                ...
# Kiribati                      0.000000
# Micronesia                    0.000000
# Solomon Islands               0.000000
# Samoa                         0.000000
# Saint Kitts and Nevis         0.000000
#
# [193 rows x 1 columns]

# %%
# Visulaization
ax = df.head(10).plot(
    kind='bar'
)

plt.title("Daily Avg Deaths Top Countries")
plt.xlabel("Country")
plt.ylabel("Daily_Avg_Deaths")
plt.xticks(rotation=45)
for container in ax.containers:
    ax.bar_label(container, fmt='%d')
plt.show()

# %%
# 6.4 How have the total deaths evolved over time in the United States?
us_deaths_over_time = (
    death_long[death_long['Country/Region'] == 'US']
    .groupby('Date')['Deaths'].sum()
)
us_deaths_over_time
# Out:
# Date
# 2020-01-22         0
# 2020-01-23         0
# 2020-01-24         0
# 2020-01-25         0
# 2020-01-26         0
#                ...
# 2021-05-25    590941
# 2021-05-26    591950
# 2021-05-27    593288
# 2021-05-28    593963
# 2021-05-29    594306
# Name: Deaths, Length: 494, dtype: int64

# %%
# Visualisation [Line Plot]
plt.figure(figsize =(12,6))
plt.plot(us_deaths_over_time.index, us_deaths_over_time.values, color = 'blue' , linewidth = 2, linestyle = '--')

plt.title('Total Covid-19 Deaths Over Time in US' , color ='red')
plt.xlabel('Date')
plt.ylabel('TotalDeaths')
plt.show()

# %%
# 6.4 How have the total deaths evolved over time in the United States?
us_deaths_over_time = (
    m[m['Country/Region'] == 'US']
    .groupby('Date')['DailyDeaths'].sum()
)
us_deaths_over_time
# Out:
# Date
# 2020-01-22       0.0
# 2020-01-23       0.0
# 2020-01-24       0.0
# 2020-01-25       0.0
# 2020-01-26       0.0
#                ...
# 2021-05-25     621.0
# 2021-05-26    1009.0
# 2021-05-27    1338.0
# 2021-05-28     675.0
# 2021-05-29     343.0
# Name: DailyDeaths, Length: 494, dtype: float64

# %%
# Visualization [Line Plot]
plt.figure(figsize = (12,6))
plt.plot(us_deaths_over_time.index , us_deaths_over_time.values , color = 'blue' , linewidth = 2,
        linestyle = '--')

plt.title('Total Covid-19 Deaths Over Time in US' , color = 'red')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.show()

# %%
# 7.2. Analyse the monthly sum of confirmed cases, deaths, and recoveries for countries 
# to understand the progression of the pandemic. [From the merged dataset]
m = merged.copy() # Shallow Copy
m = m.sort_values(['Country/Region','Date'])
m['YearMonth'] = m['Date'].dt.to_period('M')
m
# Out:
#       Country/Region       Date  Confirmed  Recovered  Deaths YearMonth
# 0        Afghanistan 2020-01-22          0          0       0   2020-01
# 1        Afghanistan 2020-01-23          0          0       0   2020-01
# 2        Afghanistan 2020-01-24          0          0       0   2020-01
# 3        Afghanistan 2020-01-25          0          0       0   2020-01
# 4        Afghanistan 2020-01-26          0          0       0   2020-01
# ...              ...        ...        ...        ...     ...       ...
# 95337       Zimbabwe 2021-05-25      38706      36517    1587   2021-05
# 95338       Zimbabwe 2021-05-26      38819      36531    1589   2021-05
# 95339       Zimbabwe 2021-05-27      38854      36541    1592   2021-05
# 95340       Zimbabwe 2021-05-28      38918      36563    1592   2021-05
# 95341       Zimbabwe 2021-05-29      38933      36578    1594   2021-05
#
# [95342 rows x 6 columns]

# %%
# Daily Confirmed
confirmed_diff = m.groupby('Country/Region')['Confirmed'].diff().clip(lower = 0)
m['DailyConfirmed'] = confirmed_diff.fillna(0)

# Daily deaths
deaths_diff = m.groupby('Country/Region')['Deaths'].diff().clip(lower = 0)
m['DailyDeaths'] = deaths_diff.fillna(0)

# Daily recovered
recovered_diff = m.groupby('Country/Region')['Recovered'].diff().clip(lower = 0)
m['DailyRecovered'] = recovered_diff.fillna(0)

m = m[['Country/Region','Date','Confirmed','Recovered','Deaths','DailyConfirmed','DailyDeaths','DailyRecovered','YearMonth']]
m
# Out:
#       Country/Region       Date  Confirmed  Recovered  Deaths  DailyConfirmed  \
# 0        Afghanistan 2020-01-22          0          0       0             0.0
# 1        Afghanistan 2020-01-23          0          0       0             0.0
# 2        Afghanistan 2020-01-24          0          0       0             0.0
# 3        Afghanistan 2020-01-25          0          0       0             0.0
# 4        Afghanistan 2020-01-26          0          0       0             0.0
# ...              ...        ...        ...        ...     ...             ...
# 95337       Zimbabwe 2021-05-25      38706      36517    1587            10.0
# 95338       Zimbabwe 2021-05-26      38819      36531    1589           113.0
# 95339       Zimbabwe 2021-05-27      38854      36541    1592            35.0
# 95340       Zimbabwe 2021-05-28      38918      36563    1592            64.0
# 95341       Zimbabwe 2021-05-29      38933      36578    1594            15.0
#
# ...

# %%
monthly_sum_trends = (
    m.groupby(['Country/Region','YearMonth'])[['DailyConfirmed', 'DailyDeaths', 'DailyRecovered']]
    .sum()
    .rename(
        columns = {
            'DailyConfirmed' : 'Confirmed', 
            'DailyDeaths' : 'Deaths', 
            'DailyRecovered' : 'Recovered'
        }
    ).astype('int64')
    .reset_index()
    .sort_values(['Country/Region','YearMonth'])
)

monthly_sum_trends
# Out:
#      Country/Region YearMonth  Confirmed  Deaths  Recovered
# 0       Afghanistan   2020-01          0       0          0
# 1       Afghanistan   2020-02          1       0          0
# 2       Afghanistan   2020-03        174       4          5
# 3       Afghanistan   2020-04       1952      60        255
# 4       Afghanistan   2020-05      13081     194       1068
# ...             ...       ...        ...     ...        ...
# 3276       Zimbabwe   2021-01      19521     854      14794
# 3277       Zimbabwe   2021-02       2701     246       6622
# 3278       Zimbabwe   2021-03        793      60       2020
# 3279       Zimbabwe   2021-04       1375      44        926
# 3280       Zimbabwe   2021-05        676      27        966
#
# [3281 rows x 5 columns]

# %%
US_trends = monthly_sum_trends[monthly_sum_trends['Country/Region'] == 'US']
Italy_trends = monthly_sum_trends[monthly_sum_trends['Country/Region'] == 'Italy']
Brazil_trends = monthly_sum_trends[monthly_sum_trends['Country/Region'] == 'Brazil']

US_trends.head()
# Out:
#      Country/Region YearMonth  Confirmed  Deaths  Recovered
# 3043             US   2020-01          7       0          0
# 3044             US   2020-02         17       1          7
# 3045             US   2020-03     192276    5369       7017
# 3046             US   2020-04     888719   60865     146923
# 3047             US   2020-05     717698   41605     293257

# %%
US_trends.plot(
    x="YearMonth",
    y=["Confirmed","Recovered","Deaths"],
    kind="line",
        figsize=(12,6),
    marker="o"
)

plt.title(f"Monthly COVID Progression - US")
plt.ylabel("Monthly Cases")
plt.xticks(rotation=45)
plt.yscale('log')
plt.show()

# %%
Italy_trends.head()
# Out:
#      Country/Region YearMonth  Confirmed  Deaths  Recovered
# 1445          Italy   2020-01          2       0          0
# 1446          Italy   2020-02       1126      29         47
# 1447          Italy   2020-03     104664   12399      15683
# 1448          Italy   2020-04      99671   15539      60216
# 1449          Italy   2020-05      27534    5448      81562

# %%
Italy_trends.plot(
    x="YearMonth",
    y=["Confirmed","Recovered","Deaths"],
    kind="line",
        figsize=(12,6),
    marker="o"
)

plt.title(f"Monthly COVID Progression - Italy")
plt.ylabel("Monthly Cases")
plt.xticks(rotation=45)
plt.yscale('log')
plt.show()

# %%
Brazil_trends.head()
# Out:
#     Country/Region YearMonth  Confirmed  Deaths  Recovered
# 391         Brazil   2020-01          0       0          0
# 392         Brazil   2020-02          2       0          0
# 393         Brazil   2020-03       5715     201        127
# 394         Brazil   2020-04      81470    5805      35808
# 395         Brazil   2020-05     427662   23308     170620

# %%
Brazil_trends.plot(
    x="YearMonth",
    y=["Confirmed","Recovered","Deaths"],
    kind="line",
        figsize=(12,6),
    marker="o"
)

plt.title(f"Monthly COVID Progression - Brazil")
plt.ylabel("Monthly Cases")
plt.xticks(rotation=45)
plt.yscale('log')
plt.show()

# %%
# 8.1. For the combined dataset, identify the three countries with the highest average death rates (deaths/confirmed cases) throughout 2020. 
# What might this indicate about the pandemic's impact in these countries?
df = monthly_sum_trends.copy() # Shallow Copy
df = df.sort_values(['Country/Region','YearMonth'])
df_2020 = df[(df['YearMonth'] >= '2020-01') & (df['YearMonth'] <= '2020-12')]
df_2020
# Out:
#      Country/Region YearMonth  Confirmed  Deaths  Recovered
# 0       Afghanistan   2020-01          0       0          0
# 1       Afghanistan   2020-02          1       0          0
# 2       Afghanistan   2020-03        174       4          5
# 3       Afghanistan   2020-04       1952      60        255
# 4       Afghanistan   2020-05      13081     194       1068
# ...             ...       ...        ...     ...        ...
# 3271       Zimbabwe   2020-08       3328     135       4217
# 3272       Zimbabwe   2020-09       1341      26       1082
# 3273       Zimbabwe   2020-10        529      15       1591
# 3274       Zimbabwe   2020-11       1583      33        588
# 3275       Zimbabwe   2020-12       3917      87       2768
#
# [2316 rows x 5 columns]

# %%
# Aggregate Totals [Confirmed ,  Deaths] Over 2020.
totals_2020 = (
    df_2020.groupby('Country/Region')[['Confirmed','Deaths']]
    .sum()
    .rename(
        columns = {
            'Confirmed' : 'Confirmed2020',
            'Deaths' : 'Deaths2020'
        }
    )
)
totals_2020
# Out:
#                     Confirmed2020  Deaths2020
# Country/Region
# Afghanistan                 51526        2191
# Albania                     58316        1181
# Algeria                     99610        3131
# Andorra                      8049          84
# Angola                      17553         408
# ...                           ...         ...
# Vietnam                      1465          36
# West Bank and Gaza         138004        1400
# Yemen                        2100         610
# Zambia                      20725         388
# Zimbabwe                    13873         363
#
# [193 rows x 2 columns]

# %%
totals_2020['DeathRate'] = (totals_2020['Deaths2020'] / totals_2020['Confirmed2020'] * 100).round(2)
totals_2020
# Out:
#                     Confirmed2020  Deaths2020  DeathRate
# Country/Region
# Afghanistan                 51526        2191       4.25
# Albania                     58316        1181       2.03
# Algeria                     99610        3131       3.14
# Andorra                      8049          84       1.04
# Angola                      17553         408       2.32
# ...                           ...         ...        ...
# Vietnam                      1465          36       2.46
# West Bank and Gaza         138004        1400       1.01
# Yemen                        2100         610      29.05
# Zambia                      20725         388       1.87
# Zimbabwe                    13873         363       2.62
#
# [193 rows x 3 columns]

# %%
top_3 = totals_2020.sort_values( by = 'DeathRate', ascending =False).head(3)
top_3
# Out:
#                 Confirmed2020  Deaths2020  DeathRate
# Country/Region
# Yemen                    2100         610      29.05
# MS Zaandam                  9           2      22.22
# Mexico                1426094      125807       8.82

# %%
# Visulaization [Bar Plot]
ax = top_3['DeathRate'].plot(kind = 'bar', figsize = (8,4))
ax.set_title('Top 3 Countries with Highest Average Death Rate %', color = 'Blue')
ax.set_xlabel('Country')
ax.set_ylabel('Death Rate %')
ax.bar_label(ax.containers[0], fmt ='%.2f%%')
plt.xticks(rotation = 45)
plt.ylim(0,40)
plt.show()

# %%
df = monthly_sum_trends.copy()
total_recoveries = df[df['Country/Region'] == 'South Africa']['Recovered'].sum() 
print(total_recoveries)
# Out:
# 1554184

# %%
total_Deaths = df[df['Country/Region'] == 'South Africa']['Deaths'].sum() 
print(total_Deaths)
# Out:
# 56363

# %%
# Visualizations [Bar Plot]
bars = plt.bar(['Total Recoveries', 'Total Deaths'], [total_recoveries, total_Deaths], color = ['#F54927','#2765F5'])
plt.title('Total Recoveries Vs Total Deaths in South Africa', color = 'red')
plt.ylabel('Counts')
plt.bar_label(bars, fmt='{:,.0f}')
plt.ylim(0,2000000)
# Remove scientific notation from y-axis
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# # Insight of This Chart
# 📌 Key Observations
# 1. Total Recoveries: ~1.55 Million
# 2. Total Deaths: ~56,363
# 3. Recoveries significantly exceed deaths.
#
# 🎯 Executive Summary (Interview Ready)
#
# South Africa recorded approximately 1.55 million recoveries compared to 56,363 deaths, indicating a significantly higher recovery outcome relative to mortality. The data suggests effective case management and a recovery-dominant outcome distribution during the observed period.

# %%
# 8.3. Analyze the ratio of recoveries to confirmed cases for the United States on a monthly basis from March 2020 to May 2021. 
# Which month experienced the highest recovery ratio, and what could be the potential reasons?
us_data = monthly_sum_trends.copy() # Shallow Copy
us_data = us_data[us_data['Country/Region'] == 'US'].sort_values('YearMonth').set_index('YearMonth')
us_data
# Out:
#           Country/Region  Confirmed  Deaths  Recovered
# YearMonth
# 2020-01               US          7       0          0
# 2020-02               US         17       1          7
# 2020-03               US     192276    5369       7017
# 2020-04               US     888719   60865     146923
# 2020-05               US     717698   41605     293257
# 2020-06               US     843456   19767     275873
# 2020-07               US    1925246   26550     717529
# 2020-08               US    1459475   29661     746665
# 2020-09               US    1208533   23399     655863
# 2020-10               US    1930191   24532     771790
# 2020-11               US    4504713   39271    1537028
# 2020-12               US    6429031   81143    1151763
# 2021-01               US    6147690   97285          0
# 2021-02               US    2401691   65636          0
# 2021-03               US    1813466   37577          0
# 2021-04               US    1884761   23736          0
# ...

# %%
recovery_ratio_us = (
    us_data['Recovered'] / us_data['Confirmed']
)
recovery_ratio_us = recovery_ratio_us.loc['2020-03' : '2021-05']
recovery_ratio_us
# Out:
# YearMonth
# 2020-03    0.036494
# 2020-04    0.165320
# 2020-05    0.408608
# 2020-06    0.327075
# 2020-07    0.372695
# 2020-08    0.511598
# 2020-09    0.542693
# 2020-10    0.399852
# 2020-11    0.341204
# 2020-12    0.179150
# 2021-01    0.000000
# 2021-02    0.000000
# 2021-03    0.000000
# 2021-04    0.000000
# 2021-05    0.000000
# Freq: M, dtype: float64

# %%
# Plotting the recovery_ratio using line_plot
fig, ax = plt.subplots(figsize = (10,6))
recovery_ratio_us.plot(kind = 'line', marker = '*', linestyle = '--')
ax.set_title('Monthly Recovery Ratio in the United States', color ='red')
ax.set_xlabel('Year_Month')
ax.set_ylabel('Recovery Ratio')
plt.show()
